# %% [markdown]
# ### with arguments
# ### without arguments

# %%
x=eval(input("Enter a number:"))
print("The square of {} is {}".format(x,x*x))
# Out:
# Enter a number:6
# The square of 6 is 36

# %%
def square():
        x=eval(input("Enter a number:"))
        print("The square of {} is {}".format(x,x*x))
square()
# Out:
# Enter a number:6
# The square of 6 is 36

# %%
def square(number):
    print("The square of {} is {}".format(number,number*number))
square(7)   
# how many variable there inside the function:number
# Out:
# The square of 7 is 49

# %%
#WAP ask there user
# get a random number between 1 to 20
# enter a number
#compare these two number
# if both are same:print("you won")
# else :print(lost)

# %%
import random
n1=eval(input("Enter a number:"))
n2=random.randint(1,20)
if n1==n2:
    print("You won")
else:
    print("lost")
print('n2')
# Out:
# Enter a number:9
# lost
# n2

# %%
import random
random_number=random.randint(1,20)
num=eval(input("Enter a number:"))
if random_number==num:
    print("you won")
else:
    print("You lost")
# Out:
# Enter a number:8
# You lost

# %%
import random
def compare():
    random_number=random.randint(1,20)
    num=eval(input("Enter a number:"))
    if random_number==num:
        print("you won")
    else:
        print("You lost ")
compare()
# Out:
# Enter a number:9
# You lost

# %%
import random
def compare(num):
    random_number=random.randint(1,20)
    if random_number==num:
        print("you won")
    else:
        print("you lost because the random number is {}".format(random_number))
compare(8)
# Out:
# you lost because the random number is 17

# %%
import random
def compare(random_num,num):
    if random_number==num:
        print("you won")
    else:
        print("you lost because the random number is {}".format(random_number))
random_num=random.randint(1,20) 
num=eval(input("Enter a number:"))
compare(random_num,num) 
# step-1:import random
# step-2:function will defin: not give
# step-3:random_num
# step-4:value
# step-5: calling the function =========> print won/loss
# Out:
# Enter a number:8
# you lost because the random number is 15

# %%
# step-1:import random
# step-4:function will defin: not give
# step-3:random_num
# step-2:value
# step-5: calling the function =========> print won/loss

# %%
# step-1:import random
# step-2:function will defin: not give
# step-3:random_num
# step-4:value
# step-5: calling the function =========> print won/loss

# %%
import random
def compare(random_num,num):
    if random_number==num:
        print("you won")
    else:
        print("you lost because the random number is {}".format(random_number))
compare(random.randint(1,20),eval(input("Enter a number:")))
# Out:
# Enter a number:9
# you lost because the random number is 15

# %%
# WAP ask the user enter sallery
#    ask the user enter tax percentage
#    calculate total tax pay

# %%
salary=eval(input("Enter the salary of the user:"))
tax_percentage=eval(input("enter the tax percentage:"))
total_tax_pay=(tax_percentage*salary)/100
print("The total tax pay by the user is {}".format(total_tax_pay))
# Out:
# Enter the salary of the user:50000
# enter the tax percentage:12
# The total tax pay by the user is 6000.0

# %%
def tax():
    salary=eval(input("Enter the salary of the user:"))
    tax_percentage=eval(input("enter the tax percentage:"))
    total_tax_pay=(tax_percentage*salary)/100
    print("The total tax pay by the user is {}".format(total_tax_pay))
tax()
# Out:
# Enter the salary of the user:50000
# enter the tax percentage:12
# The total tax pay by the user is 6000.0

# %%
# How do you pass the value
# ask by the keyboard =========== keyboard pass
def tax(salary,tax_percentage):
    total_tax_pay=(tax_percentage*salary)/100
    print("The total tax pay by the user is {}".format(total_tax_pay))
tax(eval(input("Enter the salary of the user:")),eval(input("Enter the tax percentage:")))
# Out:
# Enter the salary of the user:50000
# Enter the tax percentage:12
# The total tax pay by the user is 6000.0

# %%
# Direct pass
def tax(salary,tax_percentage):
    total_tax_pay=(tax_percentage*salary)/100
    print("The total tax pay by the user is {}".format(total_tax_pay))
tax(50000,12)
# Out:
# The total tax pay by the user is 6000.0

# %% [markdown]
# # Default Argument

# %%
# the tax percentage is always 20
# tax percent is fixed
# one value is fixed called default parameter
# default

# %%
def tax(salary,tax_percentage=20):
    total_tax_pay=(tax_percentage*salary)/100
    print("The total tax pay by the user is {}".format(total_tax_pay))
tax(50000)
# Out:
# The total tax pay by the user is 10000.0

# %%
def avg(num1,num2,num3):
    print("the avg is",((num1+num2+num3)/3))

avg(20,30,40)
# Out:
# the avg is 30.0

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("The average is:",avg)
avg(20,50)
# Out:
# num1: 20
# num2: 50
# num3: 50
# The average is: 40.0

# %%
num1=num2=num3=100
print(num1,num2,num3)
# Out:
# 100 100 100

# %%
num1,num2,num3=100
print(num1,num2,num3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 num1,num2,num3=100
#       2 print(num1,num2,num3)
#
# TypeError: cannot unpack non-iterable int object

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("The average is:",avg)
avg(20,50,20)
# Out:
# num1: 20
# num2: 50
# num3: 20
# The average is: 30.0

# %%
def avg(num1,num2=100,num3):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("The average is:",avg)
avg(200,300)
# Out:
#   Cell In[38], line 1
#     def avg(num1,num2=100,num3):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
def avg(num1,num3,num2=100):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("The average is:",avg)
avg(200,300)
# Out:
# num1: 200
# num2: 100
# num3: 300
# The average is: 200.0

# %%
def avg(num1,num2,num3=100):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("The average is:",avg)
val1=200
val2=300
avg(val1,val2)
# Out:
# num1: 200
# num2: 300
# num3: 100
# The average is: 200.0

# %%
def avg(num1,num2=100,num3):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    num3=800
    add=(num1+num2+num3)
    avg=add/3
    print("The average is:",avg)
avg(200,300,600)
# Out:
#   Cell In[41], line 1
#     def avg(num1,num2=100,num3):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
# while defining function: num3=50
# while you calling function: num3=600
# after enter inside the function :num3=800

# %% [markdown]
# - with out argument
# - with argument
# - default argument

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
complex()   # not provide: default  (0j)
# Out:
# 0j

# %%
complex(5,10)
# Out:
# (5+10j)

# %%
def summ(a=0,b=0):
    print(a*b)
    
summ(5,10)
# Out:
# 50

# %%
def summ(a=0,b=0):
    print(a*b)
    
summ()
# Out:
# 0

# %%
# WAp to ask the user to find area of circle

# %%
import math
def area():
    radius=eval(input("Enter the radius of circle:"))
    area=round((math.pi)*radius*radius,)
    print("The area of circle is ",area)
area()
# Out:
# Enter the radius of circle:5
# The area of circle is  79

# %%
import math
def area(radius):
    area=round((math.pi)*radius*radius,)
    print("The area of circle is ",area)
area(5)
# Out:
# The area of circle is  79

# %%
import math
def area(radius=5):
    area=round((math.pi)*radius*radius,)
    print("The area of circle is ",area)
radius=5   
area(radius)
# Out:
# The area of circle is  79

# %%
# without argument
import math
def area():
    try:
        radius=eval(input("Enter the radius of circle:"))
        area=round((math.pi)*radius*radius,)
        print("The area of circle is ",area)
    except Exception as error:
        print(error)
area()
# Out:
# Enter the radius of circle:5
# The area of circle is  79

# %%
# with argument
import math
def area(radius):
    try:
        area=round((math.pi)*radius*radius,)
        print("The area of circle is ",area)
    except Exception as error:
        print(error)
area(5)   # direct pass
# Out:
# The area of circle is  79

# %%
# keyboard pass
# you need to provide argument value before call the function anywhere
import math
def area(radius):
    try:
        area=round((math.pi)*radius*radius,)
        print("The area of circle is ",area)
    except Exception as error:
        print(error)
radius=eval(input("Enter the radius of circle:"))    
area(radius) 

# s-1: import math
# s-2: define function
# s-3: getting radius value
# s-4: call the function
# s-5: pi
# s-6: area
#s-7: print
# Out:
# Enter the radius of circle:5
# The area of circle is  79

# %%
# keyboard pass
# you need to provide argument value before call the function anywhere
import math
def area(radius):
    try:
        area=round((math.pi)*radius*radius,)
        print("The area of circle is ",area)
    except Exception as error:
        print(error)  
area(eval(input("Enter the radius of circle:")) ) 

# s-1: import math
# s-2: define function
# s-3: getting radius value
# s-4: call the function
# s-5: pi
# s-6: area
#s-7: print
# Out:
# Enter the radius of circle:5
# The area of circle is  79

# %%
# default argument
import math
def area(radius=5):
    try:
        area1=round((math.pi)*radius*radius,)
        print("The area of circle is ",area1)
    except Exception as error:
        print(error)  
area(radius)
# Out:
# The area of circle is  79

# %%
area1
# function is calculating area value
# but not providing that value to you
# when you want use that value outside the function========> error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 area1
#
# NameError: name 'area1' is not defined

# %% [markdown]
# **Return Concept**

# %%
def area():
    radius=eval(input("Enter the radius of circle:"))
    area=round((math.pi)*radius*radius,)
    print("The area of circle is ",area)
area()

# %%
Area=area()
# Out:
# Enter the radius of circle:5
# The area of circle is  79

# %%
Area=area()
# Out:
# Enter the radius of circle:7
# The area of circle is  153.94

# %%
import math
def area():
    radius=eval(input("Enter the radius of circle:"))
    pii=math.pi
    area=round(pii*radius*radius,2)
    print("The area of circlr is ",area)
    return(area,pii)
Area,pii=area()
print(Area)
print(pii)
# Out:
# Enter the radius of circle:5
# The area of circlr is  78.54
# 78.54
# 3.141592653589793

# %%
# ask the user enter 3 number
# find the sum and average
# Return tha average and sum

# %%
n1=eval(input('Enter the value of n1:'))
n2=eval(input('Enter the value of n2:'))
n3=eval(input('Enter the value of n3:'))
sum=n1+n2+n3
average=(sum/3)
print("The sum is {} and area is {}".format(sum,average))
# Out:
# Enter the value of n1:10
# Enter the value of n2:20
# Enter the value of n3:30
# The sum is 60 and area is 20.0

# %%
def return_the_value():
    n1=eval(input('Enter the value of n1:'))
    n2=eval(input('Enter the value of n2:'))
    n3=eval(input('Enter the value of n3:'))
    sum1=n1+n2+n3
    average=(sum1/3)
    return (sum1,average)  
total,avg=return_the_value()
print(total)
print(avg)
# Out:
# Enter the value of n1:10
# Enter the value of n2:20
# Enter the value of n3:30
# 60
# 20.0

# %%
def return_the_value(n1,n2,n3):
    sum1=n1+n2+n3
    average=(sum1/3)
    return (sum1,average)  
total,avg=return_the_value(10,20,30)
print(total)
print(avg)
#return_the_value(10,20,30) is returning two values
# sum1,average
# sum1 we are saving in a variable :total
# average we are saving in a variable:avg
# Out:
# 60
# 20.0

# %%
# Find the biggest number of 3 number
# take three number
# and find the biggest number
# and return that number

# %%
n1=eval(input("Enter the value of n1:"))
n2=eval(input("Enter the value of n2:"))
n3=eval(input("Enter the value of n3:"))
if n1>n2 and n1>n3: 
    print("n1 is greater")
elif n2>n3:
    print("n2 is greater")
else:
    print("n3 is greater")
# Out:
# Enter the value of n1:34
# Enter the value of n2:87
# Enter the value of n3:55
# n2 is greater

# %%
def greater():
    n1=eval(input("Enter the value of n1:"))
    n2=eval(input("Enter the value of n2:"))
    n3=eval(input("Enter the value of n3:"))
    if n1>n2 and n1>n3: 
        print("n1 is greater")
    elif n2>n3:
        print("n2 is greater")
    else:
        print("n3 is greater")
greater()
# Out:
# Enter the value of n1:56
# Enter the value of n2:78
# Enter the value of n3:98
# n3 is greater

# %%
def greater(n1,n2,n3):
    if n1>n2 and n1>n3: 
        print("n1 is greater")
        return(n1)
    elif n2>n3:
        print("n2 is greater")
        return(n2)
    else:
        print("n3 is greater")
        return(n3)
GREATER=greater(100,180,210) 
# It is returning only one values
# whenever condition satisfied
# Out:
# n3 is greater

# %%
def sum_avg(n1,n2,n3):
    return(n1+n2+n3,(n1+n2+n3)/3)
addition,average=sum_avg(10,20,30)
print(addition,average)
# Out:
# 60 20.0

# %%
def add(a,b):
    return(a+b)
#mul
def mul(a,b):
    return(a*b)
#sub
def sub(a,b):
    return(a-b)
# div
def div(a,b):
    return(a/b)
val_add=add(20,30)
val_mul=mul(20,30)
val_sub=sub(20,30)
val_div=div(20,30)
print(val_add,val_mul,val_sub,round(val_div,2))
# Out:
# 50 600 -10 0.67

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
add,sub,mul,div=aggregation(20,30)
print(add,sub,mul,round(div,2))
# Out:
# 50 -10 600 0.67

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
value=aggregation(20,30)
print(value)
# Out:
# (50, -10, 600, 0.6666666666666666)

# %%
def add(a,b):
    return(a+b)
#mul
def mul(a,b):
    return(a*b)
#sub
def sub(a,b):
    return(a-b)
# div
def div(a,b):
    return(a/b)
val_add=add(20,30)
val_mul=mul(20,30)
val_sub=sub(20,30)
val_div=div(20,30)
val_add,val_mul,val_sub,round(val_div,2)
# Out:
# (50, 600, -10, 0.67)

# %%
def add(a,b):return(a+b)
def sub(a,b):return(a-b)
def mul(a,b):return(a*b)
def div(a,b):return(a/b)
val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)
val_add,val_mul,val_sub,round(val_div,2)
# Out:
# (50, 600, -10, 0.67)

# %% [markdown]
# - with out argument
# - with argument
# - Default Argument
# - Return function

# %% [markdown]
# **Local Variables**
# - The variables provided inside the function:
#
#  **Global Variables**
# - The variables provided outside the Function

# %% [markdown]
# ## Local Variable

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
# Out:
# the addition of 10 and 20 is 30

# %% [markdown]
# ## Global Variable

# %%
n1=10
n2=10
def addition():
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
# Out:
# the addition of 10 and 10 is 20

# %%
# local variable
def avg():
    num1=20
    num2=30
    num3=40
    avg=(num1+num2+num3)/3
    print("The averge of {},{} and {} is {}".format(num1,num2,num3,avg))
avg()
# Out:
# The averge of 20,30 and 40 is 30.0

# %% [markdown]
# - local variables are inside the function
# - local variable values can not use outside the function
# - untill unless you return those value

# %%
# global variables
num111=20
num222=30
num333=40
def avg():
    avg=(num111+num222+num333)/3
    print("The averge of {},{} and {} is {}".format(num111,num222,num333,avg))
avg()
print(num111*num222)
# Out:
# The averge of 20,30 and 40 is 30.0
# 600

# %%
n1=20
n2=30
def addition():
    n1=200
    n2=300
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))
addition()
print(n1)
# Out:
# The addition of 200 and 300 is 500
# 20

# %%
n1=20
n2=30
def addition(n1):
    n2=300
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))
addition(500)   # 800
print(n1)       # 20
# Out:
# The addition of 500 and 300 is 800
# 20

# %%
n1=20
n2=30
def addition(n1=700):
    n2=300
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))
addition(500)
print(n1)
# step-1: n1=20
# step-2: n2=30
# step-3: function define n1=700
# step-4:
# Out:
# The addition of 500 and 300 is 800
# 20

# %%
def numbers():                          ### dought
    num1=eval(input("enter 1st no:"))
    num2=eval(input("enter 2nd no:"))
    num3=eval(input("enter 3rd no:"))
    if num2<num1>num3:
        print(num1, "is the greatest number")
        a=num1
    elif num2>num3:
        print(num2, "is the greatest number")
        a=num2
    else:
        print(num3, "is the greatest number")
        a=num
    return(a)

# %%
n1=10
def updated():
    n=n1+100
    print("n1 value inside functionn is :",n)
updated()  
print(n1)
# Out:
# n1 value inside functionn is : 110
# 10

# %%
def value():
    global number1
    number1=10
    number2=20
    print(number1)
value()
print(number1)
# Out:
# 10
# 10

# %%
def value():
    global number1
    number1=10
    number2=20
    print(number1)
value()
print(number1)
print(number2)
# Out:
# 10
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       6 value()
#       7 print(number1)
# ----> 8 print(number2)
#
# NameError: name 'number2' is not defined

# %%
def value():
    global number1,number2
    number1=10
    number2=20
    print(number1)
value()
print(number1)
print(number2)
# Out:
# 10
# 10
# 20

# %%
n_=10
def updated():
    global n_
    n_=20
    n_=n_+100
    print("n1 value inside functionn is :",n_)
updated()  
print(n_)
# Out:
# n1 value inside functionn is : 120
# 120

# %%
n1=20
n2=30
def addition(n1):
    global n2,add
    n2=300
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))
addition(500)   
print(n2)
print(add)
# Out:
# The addition of 500 and 300 is 800
# 300
# 800

# %% [markdown]
# **Function in Function**

# %%
def greet():
    print("hello")
def name():
    print("python")
greet()
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
def name():
    print("python")
    greet()
name()
# step-1: define greet()
# step-2: define name()
# step-3: calling name()
# step-4: python
# step-5: calling greet()
# step-6: hello
# Out:
# python
# hello

# %%
def greet():
    print("hello")
def name():
    print("python")
    print("how do you  do:")
    greet()
name()
# Out:
# python
# how do you  do:
# hello

# %%
def greet():
    print("hello")
    name()
def name():
    print("python")
    
greet()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
    name()
def name():
    print("python")
    greet()
greet()
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
# type:-1 ====================================
def greet():
    print("hello")
def name():
    print("python")
    print("how do you do")
greet()
name()
# type:-2 ===============================
def greet():
    print("hello")
def name():
    print("python")
    greet()
name()
# type:-3 ===============================
def greet():
    print("hello")
    name()
def name():
    print("python")
greet()

# %%
print(3)

def fun1():
    print('hello')
    print('python')
print('10+10')    
def fun2():
    print('3+5')
    print(3+5)
    fun1()
    print(good)
print(10+10)
def fun3():
    fun1()
    fun()
fun3()
# Out:
# 3
# 10+10
# 20
# hello
# python
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 16
#      14     fun1()
#      15     fun()
# ---> 16 fun3()
#
# Cell In[44], line 15, in fun3()
#      13 def fun3():
#      14     fun1()
# ---> 15     fun()
#
# NameError: name 'fun' is not defined

# %%
# create four function
#def add(a+b):
#    print(a+b)
# sub
# mul
# div
# you need to provide some print statements
# if you want enter 1: addition operation will come
# if you want enter 2: substraction operation will come
# if you want enter 3: miltiplication operation will come
# if you want enter 4: division operation will come

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def main():
    num1=eval(input("enter a number:"))
    a=eval(input("enter the value of a :"))
    b=eval(input("enter the value of b :"))
    if num1==1:
        add(a,b)
    elif num1==2:
        sub(a,b)
    elif num1==3:
        mul(a,b)
    elif num1==4:
        div(a,b)


main()
# Out:
# enter a number:3
# enter the value of a :90
# enter the value of b :80
# 7200

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def main():
    num1=eval(input("enter a number:"))
    a=eval(input("enter the value of a :"))
    b=eval(input("enter the value of b :"))
    if num1==1:
        add(a,b)
    elif num1==2:
        sub(a,b)
    elif num1==3:
        mul(a,b)
    elif num1==4:
        div(a,b)


main()
# Out:
# enter a number:1
# enter the value of a :90
# enter the value of b :80
# 170

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def main():
    num1=eval(input("enter a number:"))
    a=eval(input("enter the value of a :"))
    b=eval(input("enter the value of b :"))
    if num1==1:
        add(a,b)
    elif num1==2:
        sub(a,b)
    elif num1==3:
        mul(a,b)
    elif num1==4:
        div(a,b)


main()
# Out:
# enter a number:2
# enter the value of a :90
# enter the value of b :80
# 10

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def main():
    num1=eval(input("enter a number:"))
    a=eval(input("enter the value of a :"))
    b=eval(input("enter the value of b :"))
    if num1==1:
        add(a,b)
    elif num1==2:
        sub(a,b)
    elif num1==3:
        mul(a,b)
    elif num1==4:
        div(a,b)


main()
# Out:
# enter a number:4
# enter the value of a :90
# enter the value of b :30
# 3.0
